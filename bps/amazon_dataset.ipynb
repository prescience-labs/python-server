# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
! ls ../gdrive/My\ Drive
# Out:
#  amazon_reviews_us_Video_Games_v1_00.tsv  'Colab Notebooks'
#  amazon_reviews_us_Watches_v1_00.tsv	   crawl-300d-2M-subword
#  amazon_reviews_us_Wireless_v1_00.tsv	   crawl-300d-2M-subword.zip
#  amazon_sets_urls.txt

# %%
! mapfile -t myArray < /gdrive/My\ Drive/amazon_sets_urls.txt && for each in ${myArray[*]}; do wget ${each}; done
# Out:
# --2019-09-05 13:49:35--  https://s3.amazonaws.com/amazon-reviews-pds/tsv/amazon_reviews_us_Video_DVD_v1_00.tsv.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.107.238
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.107.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1512355451 (1.4G) [application/x-gzip]
# Saving to: ‘amazon_reviews_us_Video_DVD_v1_00.tsv.gz’
#
# amazon_reviews_us_V 100%[===================>]   1.41G  16.0MB/s    in 1m 40s
#
# 2019-09-05 13:51:16 (14.4 MB/s) - ‘amazon_reviews_us_Video_DVD_v1_00.tsv.gz’ saved [1512355451/1512355451]
#
# --2019-09-05 13:51:16--  https://s3.amazonaws.com/amazon-reviews-pds/tsv/amazon_reviews_us_Video_v1_00.tsv.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.145.149
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.145.149|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 138929896 (132M) [application/x-gzip]
# ...

# %%
! ls
# Out:
# amazon_reviews_us_Apparel_v1_00.tsv.gz
# amazon_reviews_us_Automotive_v1_00.tsv.gz
# amazon_reviews_us_Baby_v1_00.tsv.gz
# amazon_reviews_us_Beauty_v1_00.tsv.gz
# amazon_reviews_us_Books_v1_00.tsv.gz
# amazon_reviews_us_Books_v1_01.tsv.gz
# amazon_reviews_us_Books_v1_02.tsv.gz
# amazon_reviews_us_Camera_v1_00.tsv.gz
# amazon_reviews_us_Digital_Ebook_Purchase_v1_00.tsv.gz
# amazon_reviews_us_Digital_Ebook_Purchase_v1_01.tsv.gz
# amazon_reviews_us_Digital_Music_Purchase_v1_00.tsv.gz
# amazon_reviews_us_Digital_Software_v1_00.tsv.gz
# amazon_reviews_us_Digital_Video_Download_v1_00.tsv.gz
# amazon_reviews_us_Digital_Video_Games_v1_00.tsv.gz
# amazon_reviews_us_Electronics_v1_00.tsv.gz
# amazon_reviews_us_Furniture_v1_00.tsv.gz
# amazon_reviews_us_Gift_Card_v1_00.tsv.gz
# amazon_reviews_us_Grocery_v1_00.tsv.gz
# amazon_reviews_us_Health_Personal_Care_v1_00.tsv.gz
# amazon_reviews_us_Home_Entertainment_v1_00.tsv.gz
# amazon_reviews_us_Home_Improvement_v1_00.tsv.gz
# ...

# %%
! for each in *.gz; do gzip -d ${each}; done

# %%
! ls
# Out:
# amazon_reviews_us_Apparel_v1_00.tsv
# amazon_reviews_us_Automotive_v1_00.tsv
# amazon_reviews_us_Baby_v1_00.tsv
# amazon_reviews_us_Beauty_v1_00.tsv
# amazon_reviews_us_Books_v1_00.tsv
# amazon_reviews_us_Books_v1_01.tsv
# amazon_reviews_us_Books_v1_02.tsv
# amazon_reviews_us_Camera_v1_00.tsv
# amazon_reviews_us_Digital_Ebook_Purchase_v1_00.tsv
# amazon_reviews_us_Digital_Ebook_Purchase_v1_01.tsv
# amazon_reviews_us_Digital_Music_Purchase_v1_00.tsv
# amazon_reviews_us_Digital_Software_v1_00.tsv
# amazon_reviews_us_Digital_Video_Download_v1_00.tsv
# amazon_reviews_us_Digital_Video_Games_v1_00.tsv
# amazon_reviews_us_Electronics_v1_00.tsv
# amazon_reviews_us_Furniture_v1_00.tsv
# amazon_reviews_us_Gift_Card_v1_00.tsv
# amazon_reviews_us_Grocery_v1_00.tsv
# amazon_reviews_us_Health_Personal_Care_v1_00.tsv
# amazon_reviews_us_Home_Entertainment_v1_00.tsv
# amazon_reviews_us_Home_Improvement_v1_00.tsv
# amazon_reviews_us_Home_v1_00.tsv
# amazon_reviews_us_Jewelry_v1_00.tsv
# ...

# %%
! for each in *.tsv; do wc -l ${each}; done
# Out:
# 5906334 amazon_reviews_us_Apparel_v1_00.tsv
# 3514943 amazon_reviews_us_Automotive_v1_00.tsv
# 1752933 amazon_reviews_us_Baby_v1_00.tsv
# 5115667 amazon_reviews_us_Beauty_v1_00.tsv
# 10319091 amazon_reviews_us_Books_v1_00.tsv
# 6106720 amazon_reviews_us_Books_v1_01.tsv
# 3105521 amazon_reviews_us_Books_v1_02.tsv
# 1801975 amazon_reviews_us_Camera_v1_00.tsv
# 12520723 amazon_reviews_us_Digital_Ebook_Purchase_v1_00.tsv
# 5101694 amazon_reviews_us_Digital_Ebook_Purchase_v1_01.tsv
# 1688885 amazon_reviews_us_Digital_Music_Purchase_v1_00.tsv
# 102085 amazon_reviews_us_Digital_Software_v1_00.tsv
# 4057148 amazon_reviews_us_Digital_Video_Download_v1_00.tsv
# 145432 amazon_reviews_us_Digital_Video_Games_v1_00.tsv
# 3093870 amazon_reviews_us_Electronics_v1_00.tsv
# 792114 amazon_reviews_us_Furniture_v1_00.tsv
# 149087 amazon_reviews_us_Gift_Card_v1_00.tsv
# 2402459 amazon_reviews_us_Grocery_v1_00.tsv
# 5331450 amazon_reviews_us_Health_Personal_Care_v1_00.tsv
# ...

# %%
! for each in *.tsv; do head -n 1000001 ${each}

# %%
! for each in amazon_reviews_us_Lawn_and_Garden_v1_00.tsv amazon_reviews_us_Luggage_v1_00.tsv; do cp ${each} "${each}_222"; done

# %%
! for each in *.tsv; do head -n 1000001 ${each} > "${each}_new.tsv"; done

# %%
! ls
# Out:
# amazon_reviews_us_Apparel_v1_00.tsv
# amazon_reviews_us_Apparel_v1_00.tsv_new.tsv
# amazon_reviews_us_Automotive_v1_00.tsv
# amazon_reviews_us_Automotive_v1_00.tsv_new.tsv
# amazon_reviews_us_Baby_v1_00.tsv
# amazon_reviews_us_Baby_v1_00.tsv_new.tsv
# amazon_reviews_us_Beauty_v1_00.tsv
# amazon_reviews_us_Beauty_v1_00.tsv_new.tsv
# amazon_reviews_us_Books_v1_00.tsv
# amazon_reviews_us_Books_v1_00.tsv_new.tsv
# amazon_reviews_us_Books_v1_01.tsv
# amazon_reviews_us_Books_v1_01.tsv_new.tsv
# amazon_reviews_us_Books_v1_02.tsv
# amazon_reviews_us_Books_v1_02.tsv_new.tsv
# amazon_reviews_us_Camera_v1_00.tsv
# amazon_reviews_us_Camera_v1_00.tsv_new.tsv
# amazon_reviews_us_Digital_Ebook_Purchase_v1_00.tsv
# amazon_reviews_us_Digital_Ebook_Purchase_v1_00.tsv_new.tsv
# amazon_reviews_us_Digital_Ebook_Purchase_v1_01.tsv
# amazon_reviews_us_Digital_Ebook_Purchase_v1_01.tsv_new.tsv
# amazon_reviews_us_Digital_Music_Purchase_v1_00.tsv
# amazon_reviews_us_Digital_Music_Purchase_v1_00.tsv_new.tsv
# ...

# %%
! for each in *_new.tsv; do cp ${each} /gdrive/My\ Drive/; done
